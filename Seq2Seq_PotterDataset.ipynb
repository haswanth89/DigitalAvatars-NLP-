# %%
import pandas as pd

# %%
# df = pd.read_csv('./dialogs.txt' , sep='\t' , names=['Question' , 'Answer'])
# df

# %%
df = pd.read_csv('./final_data.csv' , sep=',' )
df

# Assuming df is the DataFrame
df.rename(columns={"response": "Question", "context1": "Answer"}, inplace=True)

# %%
df = df[["Question", "Answer"]]

# %%
df
# Out:
#                                                Question  \
# 0     Do you think it wise to trust Hagrid with some...
# 1     Ah, Professor, I would trust Hagrid with my life.
# 2                            Professor Dumbledore, sir.
# 3                                 Professor McGonagall.
# 4                         No problems, I trust, Hagrid?
# ...                                                 ...
# 4913                             How fast is it, Harry?
# 4914                                             Lumos.
# 4915          I solemnly swear that I am up to no good.
# 4916                                  Mischief managed.
# 4917                                               Nox.
#
#                                                  Answer
# 0                               Hagrid is bringing him.
# 1     Do you think it wise to trust Hagrid with some...
# 2     Ah, Professor, I would trust Hagrid with my life.
# 3                            Professor Dumbledore, sir.
# 4                                 Professor McGonagall.
# ...                                                 ...
# 4913                                   Yeah, let's see.
# 4914                             How fast is it, Harry?
# 4915                                             Lumos.
# 4916          I solemnly swear that I am up to no good.
# 4917                                  Mischief managed.
#
# [4918 rows x 2 columns]

# %%
# Check for null values
null_question = df['Question'].isnull().sum()
null_answer = df['Answer'].isnull().sum()

if null_question > 0:
    print("There are", null_question, "null values in the 'Question' column.")
else:
    print("There are no null values in the 'Question' column.")

if null_answer > 0:
    print("There are", null_answer, "null values in the 'Answer' column.")
else:
    print("There are no null values in the 'Answer' column.")

# Check for whitespace values
whitespace_question = df['Question'].apply(lambda x: x.isspace()).sum()
whitespace_answer = df['Answer'].apply(lambda x: x.isspace()).sum()

if whitespace_question > 0:
    print("There are", whitespace_question, "whitespace values in the 'Question' column.")
else:
    print("There are no whitespace values in the 'Question' column.")

if whitespace_answer > 0:
    print("There are", whitespace_answer, "whitespace values in the 'Answer' column.")
else:
    print("There are no whitespace values in the 'Answer' column.")
# Out:
# There are no null values in the 'Question' column.
# There are no null values in the 'Answer' column.
# There are no whitespace values in the 'Question' column.
# There are no whitespace values in the 'Answer' column.

# %%
import re

def clean_text(text):
    text = text.lower()
    text = re.sub(r'\d+', ' ', text)  # Replace all digits with spaces
    text = re.sub(r'([^\w\s])', r' \1 ', text)  # Add a space before and after each punctuation character
    text = re.sub(r'\s+', ' ', text)  # Replace all consecutive spaces with a single space
    text = text.strip()  # Remove leading and trailing spaces
    return text

df['Encoder Inputs']=df['Question'].apply(clean_text)
df['Decoder Inputs']="<sos> " + df['Answer'].apply(clean_text) + ' <eos>'
df["Decoder Targets"] = df['Answer'].apply(clean_text) + ' <eos>'

df.head()
# Out:
#                                             Question  \
# 0  Do you think it wise to trust Hagrid with some...
# 1  Ah, Professor, I would trust Hagrid with my life.
# 2                         Professor Dumbledore, sir.
# 3                              Professor McGonagall.
# 4                      No problems, I trust, Hagrid?
#
#                                               Answer  \
# 0                            Hagrid is bringing him.
# 1  Do you think it wise to trust Hagrid with some...
# 2  Ah, Professor, I would trust Hagrid with my life.
# 3                         Professor Dumbledore, sir.
# 4                              Professor McGonagall.
#
#                                       Encoder Inputs  \
# 0  do you think it wise to trust hagrid with some...
# 1  ah , professor , i would trust hagrid with my ...
# 2                       professor dumbledore , sir .
# 3                             professor mcgonagall .
# 4                   no problems , i trust , hagrid ?
#
#                                       Decoder Inputs  \
# 0               <sos> hagrid is bringing him . <eos>
# 1  <sos> do you think it wise to trust hagrid wit...
# 2  <sos> ah , professor , i would trust hagrid wi...
# 3           <sos> professor dumbledore , sir . <eos>
# 4                 <sos> professor mcgonagall . <eos>
#
#                                      Decoder Targets
# 0                     hagrid is bringing him . <eos>
# 1  do you think it wise to trust hagrid with some...
# 2  ah , professor , i would trust hagrid with my ...
# 3                 professor dumbledore , sir . <eos>
# 4                       professor mcgonagall . <eos>

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Define the maximum number of words to keep based on word frequency
num_words = 10000

# Define the maximum sequence length
max_seq_length = 10

# Create a tokenizer and fit it on the 'Encoder Inputs' and 'Decoder Inputs' columns of the DataFrame
tokenizer = Tokenizer(num_words=num_words, oov_token='<unk>')
tokenizer.fit_on_texts(df['Encoder Inputs'].tolist() + df['Decoder Inputs'].tolist())

# Convert the text data to sequences of integers using the tokenizer
encoder_inputs = tokenizer.texts_to_sequences(df['Encoder Inputs'].tolist())
decoder_inputs = tokenizer.texts_to_sequences(df['Decoder Inputs'].tolist())
decoder_targets = tokenizer.texts_to_sequences(df['Decoder Targets'].tolist())

# Pad the sequences to ensure they all have the same length
encoder_inputs = pad_sequences(encoder_inputs, maxlen=max_seq_length, padding='post', truncating='post')
decoder_inputs = pad_sequences(decoder_inputs, maxlen=max_seq_length, padding='post', truncating='post')
decoder_targets = pad_sequences(decoder_targets, maxlen=max_seq_length, padding='post', truncating='post')
# Out:
# 2024-03-27 20:19:37.069352: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-27 20:19:37.917427: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2024-03-27 20:19:37.917537: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2024-03-27 20:19:37.917548: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
decoder_targets[1:3]
# Out:
# array([[ 30,   5,  61,  10, 790,   8, 424, 108,  51, 101],
#        [241,  69,   7,  81, 424, 108,  51,  36, 304,   3]], dtype=int32)

# %%
df['Decoder Targets'][1:3]
# Out:
# 1    do you think it wise to trust hagrid with some...
# 2    ah , professor , i would trust hagrid with my ...
# Name: Decoder Targets, dtype: object

# %%
# Get the vocabulary size of the tokenizer
vocab_size = len(tokenizer.word_index)
print('Vocabulary Size: %d' % vocab_size)
# Out:
# Vocabulary Size: 3207

# %%
print(encoder_inputs.shape , "\n" , decoder_inputs.shape , "\n" , decoder_targets.shape)
# Out:
# (4918, 10)
#  (4918, 10)
#  (4918, 10)

# %%
from sklearn.model_selection import train_test_split

# Split the data into train and test sets
encoder_inputs_train, encoder_inputs_test, decoder_inputs_train, decoder_inputs_test, decoder_targets_train, decoder_targets_test = train_test_split(encoder_inputs, decoder_inputs, decoder_targets, test_size=0.2, random_state=42)

# Print the shapes of the train and test sets
print("Train set shapes:", encoder_inputs_train.shape, decoder_inputs_train.shape, decoder_targets_train.shape)
print("Test set shapes:", encoder_inputs_test.shape, decoder_inputs_test.shape, decoder_targets_test.shape)
# Out:
# Train set shapes: (3934, 10) (3934, 10) (3934, 10)
# Test set shapes: (984, 10) (984, 10) (984, 10)

# %%
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding
from tensorflow.keras.models import Model

num_encoder_tokens = len(tokenizer.word_index) + 1
num_decoder_tokens = len(tokenizer.word_index) + 1
latent_dim = 64
embedding_dim = 50

# Define the input sequence
encoder_inputs = Input(shape=(max_seq_length,))

#_________________Embedding________________________

encoder_embedding = Embedding(num_encoder_tokens, embedding_dim , mask_zero=True)
encoder_inputs_embedded = encoder_embedding(encoder_inputs)


#_________________Encoder________________________

# Encoder - LSTM1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(encoder_inputs_embedded)

# Encoder - LSTM2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# Encoder - LSTM2
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)
#______________________________________________

# Discard the encoder outputs and only keep the states
encoder_states = [state_h, state_c]

# Define the decoder input sequence
decoder_inputs = Input(shape=(max_seq_length,))

# Add an embedding layer
decoder_embedding = Embedding(num_decoder_tokens, embedding_dim , mask_zero=True)
decoder_inputs_embedded = decoder_embedding(decoder_inputs)

#_________________Decoder________________________

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)

# Get the decoder outputs and states
decoder_outputs, _, _ = decoder_lstm(decoder_inputs_embedded, initial_state=encoder_states)

# Define the decoder output layer
decoder_dense = Dense(num_decoder_tokens, activation='softmax')

# Get the decoder outputs
decoder_outputs = decoder_dense(decoder_outputs)

# Define the Seq2Seq model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

model.summary()
# Out:
# 2024-03-27 20:19:39.318898: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-27 20:19:39.360680: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2024-03-27 20:19:39.360710: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2024-03-27 20:19:39.361102: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 10)]         0           []
#
#  embedding (Embedding)          (None, 10, 50)       160400      ['input_1[0][0]']
#
#  lstm (LSTM)                    [(None, 10, 64),     29440       ['embedding[0][0]']
#                                  (None, 64),
#                                  (None, 64)]
#
#  input_2 (InputLayer)           [(None, 10)]         0           []
#
#  lstm_1 (LSTM)                  [(None, 10, 64),     33024       ['lstm[0][0]']
#                                  (None, 64),
#                                  (None, 64)]
#
#  embedding_1 (Embedding)        (None, 10, 50)       160400      ['input_2[0][0]']
#
#  lstm_2 (LSTM)                  [(None, 10, 64),     33024       ['lstm_1[0][0]']
#                                  (None, 64),
#                                  (None, 64)]
#
#  lstm_3 (LSTM)                  [(None, 10, 64),     29440       ['embedding_1[0][0]',
#                                  (None, 64),                      'lstm_2[0][1]',
#                                  (None, 64)]                      'lstm_2[0][2]']
#
#  dense (Dense)                  (None, 10, 3208)     208520      ['lstm_3[0][0]']
#
# ==================================================================================================
# Total params: 654,248
# Trainable params: 654,248
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import to_categorical
import tensorflow as tf

# early_stopping = tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=15)


batch_size = 32
epochs = 300

# One-hot encode the decoder targets
decoder_targets_train = to_categorical(decoder_targets_train, num_decoder_tokens)
decoder_targets_test = to_categorical(decoder_targets_test, num_decoder_tokens)

# Define the Seq2Seq model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'] , sample_weight_mode='temporal')

# Train the model
model.fit([encoder_inputs_train, decoder_inputs_train], decoder_targets_train,
          validation_data=([encoder_inputs_test, decoder_inputs_test], decoder_targets_test),
          batch_size=batch_size, epochs=epochs )
          # batch_size=batch_size, epochs=epochs , callbacks=[early_stopping])
# Out:
# Epoch 1/300
# 123/123 [==============================] - 20s 73ms/step - loss: 6.2145 - accuracy: 0.1026 - val_loss: 5.4846 - val_accuracy: 0.1095
# Epoch 2/300
# 123/123 [==============================] - 8s 63ms/step - loss: 5.3020 - accuracy: 0.1381 - val_loss: 5.2686 - val_accuracy: 0.1517
# Epoch 3/300
# 123/123 [==============================] - 7s 56ms/step - loss: 5.0664 - accuracy: 0.1993 - val_loss: 5.1148 - val_accuracy: 0.2267
# Epoch 4/300
# 123/123 [==============================] - 7s 56ms/step - loss: 4.9126 - accuracy: 0.2268 - val_loss: 5.0215 - val_accuracy: 0.2372
# Epoch 5/300
# 123/123 [==============================] - 7s 56ms/step - loss: 4.7915 - accuracy: 0.2393 - val_loss: 4.9346 - val_accuracy: 0.2605
# Epoch 6/300
# 123/123 [==============================] - 7s 57ms/step - loss: 4.6824 - accuracy: 0.2596 - val_loss: 4.8755 - val_accuracy: 0.2656
# Epoch 7/300
# 123/123 [==============================] - 7s 56ms/step - loss: 4.6044 - accuracy: 0.2624 - val_loss: 4.8402 - val_accuracy: 0.2671
# Epoch 8/300
# 123/123 [==============================] - 7s 59ms/step - loss: 4.5490 - accuracy: 0.2645 - val_loss: 4.8187 - val_accuracy: 0.2679
# Epoch 9/300
# 123/123 [==============================] - 7s 57ms/step - loss: 4.4999 - accuracy: 0.2678 - val_loss: 4.8093 - val_accuracy: 0.2691
# Epoch 10/300
# 123/123 [==============================] - 8s 64ms/step - loss: 4.4595 - accuracy: 0.2716 - val_loss: 4.7947 - val_accuracy: 0.2697
# Epoch 11/300
# 123/123 [==============================] - 7s 58ms/step - loss: 4.4236 - accuracy: 0.2749 - val_loss: 4.7890 - val_accuracy: 0.2724
# Epoch 12/300
# 123/123 [==============================] - 7s 57ms/step - loss: 4.3875 - accuracy: 0.2793 - val_loss: 4.7678 - val_accuracy: 0.2746
# Epoch 13/300
# 123/123 [==============================] - 7s 57ms/step - loss: 4.3496 - accuracy: 0.2840 - val_loss: 4.7564 - val_accuracy: 0.2787
# Epoch 14/300
# 123/123 [==============================] - 7s 57ms/step - loss: 4.3129 - accuracy: 0.2874 - val_loss: 4.7399 - val_accuracy: 0.2808
# Epoch 15/300
# 123/123 [==============================] - 7s 58ms/step - loss: 4.2742 - accuracy: 0.2900 - val_loss: 4.7261 - val_accuracy: 0.2802
# Epoch 16/300
# 123/123 [==============================] - 7s 56ms/step - loss: 4.2379 - accuracy: 0.2914 - val_loss: 4.7131 - val_accuracy: 0.2829
# Epoch 17/300
# 123/123 [==============================] - 7s 57ms/step - loss: 4.1993 - accuracy: 0.2956 - val_loss: 4.7036 - val_accuracy: 0.2838
# Epoch 18/300
# 123/123 [==============================] - 7s 57ms/step - loss: 4.1653 - accuracy: 0.3007 - val_loss: 4.6938 - val_accuracy: 0.2918
# Epoch 19/300
# 123/123 [==============================] - 8s 64ms/step - loss: 4.1291 - accuracy: 0.3040 - val_loss: 4.6839 - val_accuracy: 0.2985
# Epoch 20/300
# 123/123 [==============================] - 7s 56ms/step - loss: 4.0943 - accuracy: 0.3091 - val_loss: 4.6783 - val_accuracy: 0.2982
# Epoch 21/300
# 123/123 [==============================] - 7s 57ms/step - loss: 4.0605 - accuracy: 0.3140 - val_loss: 4.6748 - val_accuracy: 0.2987
# Epoch 22/300
# 123/123 [==============================] - 7s 56ms/step - loss: 4.0274 - accuracy: 0.3169 - val_loss: 4.6676 - val_accuracy: 0.3022
# Epoch 23/300
# 123/123 [==============================] - 7s 56ms/step - loss: 3.9962 - accuracy: 0.3192 - val_loss: 4.6662 - val_accuracy: 0.3036
# Epoch 24/300
# 123/123 [==============================] - 7s 57ms/step - loss: 3.9647 - accuracy: 0.3218 - val_loss: 4.6599 - val_accuracy: 0.3034
# Epoch 25/300
# 123/123 [==============================] - 7s 56ms/step - loss: 3.9310 - accuracy: 0.3261 - val_loss: 4.6589 - val_accuracy: 0.3055
# Epoch 26/300
# 123/123 [==============================] - 7s 57ms/step - loss: 3.9014 - accuracy: 0.3287 - val_loss: 4.6578 - val_accuracy: 0.3043
# Epoch 27/300
# 123/123 [==============================] - 8s 63ms/step - loss: 3.8674 - accuracy: 0.3314 - val_loss: 4.6621 - val_accuracy: 0.3107
# Epoch 28/300
# 123/123 [==============================] - 7s 58ms/step - loss: 3.8405 - accuracy: 0.3347 - val_loss: 4.6632 - val_accuracy: 0.3085
# Epoch 29/300
# 123/123 [==============================] - 7s 57ms/step - loss: 3.8107 - accuracy: 0.3362 - val_loss: 4.6582 - val_accuracy: 0.3069
# Epoch 30/300
# 123/123 [==============================] - 7s 57ms/step - loss: 3.7821 - accuracy: 0.3376 - val_loss: 4.6637 - val_accuracy: 0.3077
# Epoch 31/300
# 123/123 [==============================] - 7s 58ms/step - loss: 3.7547 - accuracy: 0.3404 - val_loss: 4.6649 - val_accuracy: 0.3060
# Epoch 32/300
# 123/123 [==============================] - 7s 56ms/step - loss: 3.7268 - accuracy: 0.3413 - val_loss: 4.6737 - val_accuracy: 0.3085
# Epoch 33/300
# 123/123 [==============================] - 7s 57ms/step - loss: 3.7003 - accuracy: 0.3436 - val_loss: 4.6756 - val_accuracy: 0.3109
# Epoch 34/300
# 123/123 [==============================] - 7s 56ms/step - loss: 3.6730 - accuracy: 0.3454 - val_loss: 4.6826 - val_accuracy: 0.3063
# Epoch 35/300
# 123/123 [==============================] - 7s 59ms/step - loss: 3.6450 - accuracy: 0.3471 - val_loss: 4.6873 - val_accuracy: 0.3051
# Epoch 36/300
# 123/123 [==============================] - 8s 62ms/step - loss: 3.6208 - accuracy: 0.3487 - val_loss: 4.6949 - val_accuracy: 0.3094
# Epoch 37/300
# 123/123 [==============================] - 7s 58ms/step - loss: 3.5947 - accuracy: 0.3503 - val_loss: 4.6925 - val_accuracy: 0.3081
# Epoch 38/300
# 123/123 [==============================] - 7s 56ms/step - loss: 3.5692 - accuracy: 0.3518 - val_loss: 4.7080 - val_accuracy: 0.3081
# Epoch 39/300
# 123/123 [==============================] - 7s 57ms/step - loss: 3.5459 - accuracy: 0.3540 - val_loss: 4.7130 - val_accuracy: 0.3047
# Epoch 40/300
# 123/123 [==============================] - 7s 57ms/step - loss: 3.5198 - accuracy: 0.3549 - val_loss: 4.7184 - val_accuracy: 0.3087
# Epoch 41/300
# 123/123 [==============================] - 7s 57ms/step - loss: 3.4971 - accuracy: 0.3573 - val_loss: 4.7335 - val_accuracy: 0.3062
# Epoch 42/300
# 123/123 [==============================] - 7s 57ms/step - loss: 3.4705 - accuracy: 0.3579 - val_loss: 4.7399 - val_accuracy: 0.3049
# Epoch 43/300
# 123/123 [==============================] - 7s 56ms/step - loss: 3.4491 - accuracy: 0.3604 - val_loss: 4.7451 - val_accuracy: 0.3089
# Epoch 44/300
# 123/123 [==============================] - 8s 64ms/step - loss: 3.4236 - accuracy: 0.3615 - val_loss: 4.7604 - val_accuracy: 0.3062
# Epoch 45/300
# 123/123 [==============================] - 7s 58ms/step - loss: 3.4032 - accuracy: 0.3627 - val_loss: 4.7707 - val_accuracy: 0.3045
# Epoch 46/300
# 123/123 [==============================] - 7s 58ms/step - loss: 3.3792 - accuracy: 0.3650 - val_loss: 4.7834 - val_accuracy: 0.3029
# Epoch 47/300
# 123/123 [==============================] - 7s 56ms/step - loss: 3.3552 - accuracy: 0.3665 - val_loss: 4.7978 - val_accuracy: 0.3044
# Epoch 48/300
# 123/123 [==============================] - 7s 58ms/step - loss: 3.3339 - accuracy: 0.3680 - val_loss: 4.8036 - val_accuracy: 0.3047
# Epoch 49/300
# 123/123 [==============================] - 7s 57ms/step - loss: 3.3124 - accuracy: 0.3702 - val_loss: 4.8047 - val_accuracy: 0.3069
# Epoch 50/300
# 123/123 [==============================] - 7s 58ms/step - loss: 3.2906 - accuracy: 0.3722 - val_loss: 4.8342 - val_accuracy: 0.3027
# Epoch 51/300
# 123/123 [==============================] - 7s 56ms/step - loss: 3.2696 - accuracy: 0.3737 - val_loss: 4.8403 - val_accuracy: 0.3054
# Epoch 52/300
# 123/123 [==============================] - 8s 62ms/step - loss: 3.2475 - accuracy: 0.3748 - val_loss: 4.8571 - val_accuracy: 0.3047
# Epoch 53/300
# 123/123 [==============================] - 7s 58ms/step - loss: 3.2244 - accuracy: 0.3777 - val_loss: 4.8704 - val_accuracy: 0.3030
# Epoch 54/300
# 123/123 [==============================] - 7s 57ms/step - loss: 3.2045 - accuracy: 0.3796 - val_loss: 4.8781 - val_accuracy: 0.3060
# Epoch 55/300
# 123/123 [==============================] - 7s 57ms/step - loss: 3.1849 - accuracy: 0.3817 - val_loss: 4.8959 - val_accuracy: 0.3066
# Epoch 56/300
# 123/123 [==============================] - 7s 58ms/step - loss: 3.1643 - accuracy: 0.3836 - val_loss: 4.9028 - val_accuracy: 0.3029
# Epoch 57/300
# 123/123 [==============================] - 7s 57ms/step - loss: 3.1434 - accuracy: 0.3864 - val_loss: 4.9152 - val_accuracy: 0.3044
# Epoch 58/300
# 123/123 [==============================] - 7s 56ms/step - loss: 3.1197 - accuracy: 0.3891 - val_loss: 4.9354 - val_accuracy: 0.3070
# Epoch 59/300
# 123/123 [==============================] - 7s 58ms/step - loss: 3.1004 - accuracy: 0.3921 - val_loss: 4.9478 - val_accuracy: 0.3037
# Epoch 60/300
# 123/123 [==============================] - 7s 57ms/step - loss: 3.0821 - accuracy: 0.3941 - val_loss: 4.9605 - val_accuracy: 0.3047
# Epoch 61/300
# 123/123 [==============================] - 8s 65ms/step - loss: 3.0631 - accuracy: 0.3958 - val_loss: 4.9708 - val_accuracy: 0.3020
# Epoch 62/300
# 123/123 [==============================] - 7s 58ms/step - loss: 3.0424 - accuracy: 0.3980 - val_loss: 4.9901 - val_accuracy: 0.3033
# Epoch 63/300
# 123/123 [==============================] - 7s 59ms/step - loss: 3.0244 - accuracy: 0.4012 - val_loss: 5.0019 - val_accuracy: 0.3045
# Epoch 64/300
# 123/123 [==============================] - 7s 58ms/step - loss: 3.0069 - accuracy: 0.4042 - val_loss: 5.0143 - val_accuracy: 0.3009
# Epoch 65/300
# 123/123 [==============================] - 7s 58ms/step - loss: 2.9867 - accuracy: 0.4053 - val_loss: 5.0288 - val_accuracy: 0.3038
# Epoch 66/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.9696 - accuracy: 0.4084 - val_loss: 5.0453 - val_accuracy: 0.3007
# Epoch 67/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.9502 - accuracy: 0.4103 - val_loss: 5.0669 - val_accuracy: 0.3023
# Epoch 68/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.9318 - accuracy: 0.4130 - val_loss: 5.0733 - val_accuracy: 0.3026
# Epoch 69/300
# 123/123 [==============================] - 8s 63ms/step - loss: 2.9143 - accuracy: 0.4154 - val_loss: 5.0884 - val_accuracy: 0.3030
# Epoch 70/300
# 123/123 [==============================] - 7s 56ms/step - loss: 2.8985 - accuracy: 0.4179 - val_loss: 5.1049 - val_accuracy: 0.3026
# Epoch 71/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.8794 - accuracy: 0.4210 - val_loss: 5.1257 - val_accuracy: 0.3005
# Epoch 72/300
# 123/123 [==============================] - 7s 58ms/step - loss: 2.8631 - accuracy: 0.4229 - val_loss: 5.1293 - val_accuracy: 0.3014
# Epoch 73/300
# 123/123 [==============================] - 7s 58ms/step - loss: 2.8460 - accuracy: 0.4239 - val_loss: 5.1529 - val_accuracy: 0.3015
# Epoch 74/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.8312 - accuracy: 0.4256 - val_loss: 5.1612 - val_accuracy: 0.3043
# Epoch 75/300
# 123/123 [==============================] - 7s 55ms/step - loss: 2.8122 - accuracy: 0.4271 - val_loss: 5.1719 - val_accuracy: 0.3036
# Epoch 76/300
# 123/123 [==============================] - 7s 55ms/step - loss: 2.7983 - accuracy: 0.4308 - val_loss: 5.1863 - val_accuracy: 0.3026
# Epoch 77/300
# 123/123 [==============================] - 7s 59ms/step - loss: 2.7815 - accuracy: 0.4325 - val_loss: 5.2021 - val_accuracy: 0.2993
# Epoch 78/300
# 123/123 [==============================] - 8s 64ms/step - loss: 2.7648 - accuracy: 0.4353 - val_loss: 5.2220 - val_accuracy: 0.3020
# Epoch 79/300
# 123/123 [==============================] - 7s 56ms/step - loss: 2.7501 - accuracy: 0.4387 - val_loss: 5.2366 - val_accuracy: 0.3008
# Epoch 80/300
# 123/123 [==============================] - 8s 65ms/step - loss: 2.7369 - accuracy: 0.4383 - val_loss: 5.2490 - val_accuracy: 0.3009
# Epoch 81/300
# 123/123 [==============================] - 7s 58ms/step - loss: 2.7190 - accuracy: 0.4426 - val_loss: 5.2763 - val_accuracy: 0.3002
# Epoch 82/300
# 123/123 [==============================] - 7s 61ms/step - loss: 2.7035 - accuracy: 0.4445 - val_loss: 5.2893 - val_accuracy: 0.3041
# Epoch 83/300
# 123/123 [==============================] - 7s 59ms/step - loss: 2.6930 - accuracy: 0.4462 - val_loss: 5.3003 - val_accuracy: 0.3011
# Epoch 84/300
# 123/123 [==============================] - 7s 59ms/step - loss: 2.6778 - accuracy: 0.4483 - val_loss: 5.3261 - val_accuracy: 0.3011
# Epoch 85/300
# 123/123 [==============================] - 8s 62ms/step - loss: 2.6617 - accuracy: 0.4500 - val_loss: 5.3333 - val_accuracy: 0.2996
# Epoch 86/300
# 123/123 [==============================] - 9s 71ms/step - loss: 2.6483 - accuracy: 0.4514 - val_loss: 5.3496 - val_accuracy: 0.2986
# Epoch 87/300
# 123/123 [==============================] - 7s 61ms/step - loss: 2.6347 - accuracy: 0.4540 - val_loss: 5.3691 - val_accuracy: 0.3009
# Epoch 88/300
# 123/123 [==============================] - 7s 58ms/step - loss: 2.6208 - accuracy: 0.4555 - val_loss: 5.3926 - val_accuracy: 0.2989
# Epoch 89/300
# 123/123 [==============================] - 7s 59ms/step - loss: 2.6090 - accuracy: 0.4587 - val_loss: 5.3964 - val_accuracy: 0.3011
# Epoch 90/300
# 123/123 [==============================] - 7s 59ms/step - loss: 2.5943 - accuracy: 0.4599 - val_loss: 5.4107 - val_accuracy: 0.2982
# Epoch 91/300
# 123/123 [==============================] - 7s 58ms/step - loss: 2.5818 - accuracy: 0.4631 - val_loss: 5.4321 - val_accuracy: 0.2956
# Epoch 92/300
# 123/123 [==============================] - 7s 58ms/step - loss: 2.5684 - accuracy: 0.4619 - val_loss: 5.4478 - val_accuracy: 0.3001
# Epoch 93/300
# 123/123 [==============================] - 7s 58ms/step - loss: 2.5548 - accuracy: 0.4667 - val_loss: 5.4586 - val_accuracy: 0.2994
# Epoch 94/300
# 123/123 [==============================] - 8s 65ms/step - loss: 2.5418 - accuracy: 0.4675 - val_loss: 5.4879 - val_accuracy: 0.2989
# Epoch 95/300
# 123/123 [==============================] - 7s 58ms/step - loss: 2.5296 - accuracy: 0.4695 - val_loss: 5.4962 - val_accuracy: 0.2990
# Epoch 96/300
# 123/123 [==============================] - 7s 58ms/step - loss: 2.5180 - accuracy: 0.4705 - val_loss: 5.5095 - val_accuracy: 0.2993
# Epoch 97/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.5050 - accuracy: 0.4732 - val_loss: 5.5273 - val_accuracy: 0.2957
# Epoch 98/300
# 123/123 [==============================] - 7s 58ms/step - loss: 2.4954 - accuracy: 0.4757 - val_loss: 5.5313 - val_accuracy: 0.2954
# Epoch 99/300
# 123/123 [==============================] - 7s 56ms/step - loss: 2.4808 - accuracy: 0.4770 - val_loss: 5.5543 - val_accuracy: 0.2968
# Epoch 100/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.4703 - accuracy: 0.4804 - val_loss: 5.5784 - val_accuracy: 0.2971
# Epoch 101/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.4585 - accuracy: 0.4815 - val_loss: 5.5903 - val_accuracy: 0.2960
# Epoch 102/300
# 123/123 [==============================] - 8s 63ms/step - loss: 2.4469 - accuracy: 0.4827 - val_loss: 5.6138 - val_accuracy: 0.2946
# Epoch 103/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.4341 - accuracy: 0.4859 - val_loss: 5.6207 - val_accuracy: 0.2962
# Epoch 104/300
# 123/123 [==============================] - 7s 58ms/step - loss: 2.4246 - accuracy: 0.4872 - val_loss: 5.6466 - val_accuracy: 0.2927
# Epoch 105/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.4153 - accuracy: 0.4877 - val_loss: 5.6617 - val_accuracy: 0.2947
# Epoch 106/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.4059 - accuracy: 0.4892 - val_loss: 5.6576 - val_accuracy: 0.2976
# Epoch 107/300
# 123/123 [==============================] - 7s 58ms/step - loss: 2.3918 - accuracy: 0.4915 - val_loss: 5.6771 - val_accuracy: 0.2953
# Epoch 108/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.3837 - accuracy: 0.4930 - val_loss: 5.6836 - val_accuracy: 0.2949
# Epoch 109/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.3715 - accuracy: 0.4954 - val_loss: 5.7178 - val_accuracy: 0.2971
# Epoch 110/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.3602 - accuracy: 0.4973 - val_loss: 5.7256 - val_accuracy: 0.2973
# Epoch 111/300
# 123/123 [==============================] - 8s 64ms/step - loss: 2.3519 - accuracy: 0.4995 - val_loss: 5.7409 - val_accuracy: 0.2929
# Epoch 112/300
# 123/123 [==============================] - 7s 58ms/step - loss: 2.3396 - accuracy: 0.5003 - val_loss: 5.7630 - val_accuracy: 0.2940
# Epoch 113/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.3296 - accuracy: 0.5027 - val_loss: 5.7747 - val_accuracy: 0.2975
# Epoch 114/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.3214 - accuracy: 0.5047 - val_loss: 5.7981 - val_accuracy: 0.2929
# Epoch 115/300
# 123/123 [==============================] - 7s 59ms/step - loss: 2.3123 - accuracy: 0.5065 - val_loss: 5.8134 - val_accuracy: 0.2929
# Epoch 116/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.3030 - accuracy: 0.5076 - val_loss: 5.8029 - val_accuracy: 0.2951
# Epoch 117/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.2936 - accuracy: 0.5095 - val_loss: 5.8264 - val_accuracy: 0.2918
# Epoch 118/300
# 123/123 [==============================] - 7s 56ms/step - loss: 2.2844 - accuracy: 0.5116 - val_loss: 5.8499 - val_accuracy: 0.2922
# Epoch 119/300
# 123/123 [==============================] - 8s 63ms/step - loss: 2.2720 - accuracy: 0.5133 - val_loss: 5.8661 - val_accuracy: 0.2929
# Epoch 120/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.2624 - accuracy: 0.5152 - val_loss: 5.8826 - val_accuracy: 0.2931
# Epoch 121/300
# 123/123 [==============================] - 7s 55ms/step - loss: 2.2555 - accuracy: 0.5168 - val_loss: 5.8929 - val_accuracy: 0.2940
# Epoch 122/300
# 123/123 [==============================] - 7s 55ms/step - loss: 2.2456 - accuracy: 0.5172 - val_loss: 5.9073 - val_accuracy: 0.2940
# Epoch 123/300
# 123/123 [==============================] - 7s 56ms/step - loss: 2.2349 - accuracy: 0.5200 - val_loss: 5.9259 - val_accuracy: 0.2906
# Epoch 124/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.2270 - accuracy: 0.5207 - val_loss: 5.9406 - val_accuracy: 0.2913
# Epoch 125/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.2210 - accuracy: 0.5211 - val_loss: 5.9542 - val_accuracy: 0.2902
# Epoch 126/300
# 123/123 [==============================] - 7s 56ms/step - loss: 2.2120 - accuracy: 0.5248 - val_loss: 5.9716 - val_accuracy: 0.2893
# Epoch 127/300
# 123/123 [==============================] - 7s 56ms/step - loss: 2.2018 - accuracy: 0.5270 - val_loss: 5.9754 - val_accuracy: 0.2916
# Epoch 128/300
# 123/123 [==============================] - 8s 67ms/step - loss: 2.1918 - accuracy: 0.5272 - val_loss: 5.9853 - val_accuracy: 0.2921
# Epoch 129/300
# 123/123 [==============================] - 7s 59ms/step - loss: 2.1834 - accuracy: 0.5287 - val_loss: 6.0186 - val_accuracy: 0.2891
# Epoch 130/300
# 123/123 [==============================] - 7s 60ms/step - loss: 2.1764 - accuracy: 0.5310 - val_loss: 6.0274 - val_accuracy: 0.2922
# Epoch 131/300
# 123/123 [==============================] - 7s 61ms/step - loss: 2.1681 - accuracy: 0.5319 - val_loss: 6.0472 - val_accuracy: 0.2880
# Epoch 132/300
# 123/123 [==============================] - 7s 61ms/step - loss: 2.1615 - accuracy: 0.5321 - val_loss: 6.0573 - val_accuracy: 0.2893
# Epoch 133/300
# 123/123 [==============================] - 7s 61ms/step - loss: 2.1528 - accuracy: 0.5352 - val_loss: 6.0700 - val_accuracy: 0.2888
# Epoch 134/300
# 123/123 [==============================] - 7s 61ms/step - loss: 2.1444 - accuracy: 0.5356 - val_loss: 6.0694 - val_accuracy: 0.2892
# Epoch 135/300
# 123/123 [==============================] - 8s 62ms/step - loss: 2.1376 - accuracy: 0.5385 - val_loss: 6.0951 - val_accuracy: 0.2864
# Epoch 136/300
# 123/123 [==============================] - 8s 67ms/step - loss: 2.1286 - accuracy: 0.5383 - val_loss: 6.1096 - val_accuracy: 0.2880
# Epoch 137/300
# 123/123 [==============================] - 7s 60ms/step - loss: 2.1190 - accuracy: 0.5426 - val_loss: 6.1350 - val_accuracy: 0.2860
# Epoch 138/300
# 123/123 [==============================] - 7s 59ms/step - loss: 2.1117 - accuracy: 0.5439 - val_loss: 6.1446 - val_accuracy: 0.2882
# Epoch 139/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.1066 - accuracy: 0.5433 - val_loss: 6.1482 - val_accuracy: 0.2864
# Epoch 140/300
# 123/123 [==============================] - 7s 59ms/step - loss: 2.0971 - accuracy: 0.5444 - val_loss: 6.1613 - val_accuracy: 0.2898
# Epoch 141/300
# 123/123 [==============================] - 7s 59ms/step - loss: 2.0915 - accuracy: 0.5472 - val_loss: 6.1891 - val_accuracy: 0.2877
# Epoch 142/300
# 123/123 [==============================] - 7s 60ms/step - loss: 2.0815 - accuracy: 0.5481 - val_loss: 6.1868 - val_accuracy: 0.2885
# Epoch 143/300
# 123/123 [==============================] - 7s 60ms/step - loss: 2.0728 - accuracy: 0.5496 - val_loss: 6.2166 - val_accuracy: 0.2867
# Epoch 144/300
# 123/123 [==============================] - 8s 68ms/step - loss: 2.0683 - accuracy: 0.5505 - val_loss: 6.2225 - val_accuracy: 0.2873
# Epoch 145/300
# 123/123 [==============================] - 7s 60ms/step - loss: 2.0569 - accuracy: 0.5532 - val_loss: 6.2264 - val_accuracy: 0.2893
# Epoch 146/300
# 123/123 [==============================] - 7s 59ms/step - loss: 2.0492 - accuracy: 0.5557 - val_loss: 6.2603 - val_accuracy: 0.2900
# Epoch 147/300
# 123/123 [==============================] - 8s 63ms/step - loss: 2.0090 - accuracy: 0.5615 - val_loss: 6.3319 - val_accuracy: 0.2830
# Epoch 153/300
# 123/123 [==============================] - 7s 57ms/step - loss: 2.0032 - accuracy: 0.5626 - val_loss: 6.3434 - val_accuracy: 0.2874
# Epoch 154/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.9977 - accuracy: 0.5651 - val_loss: 6.3659 - val_accuracy: 0.2845
# Epoch 155/300
# 123/123 [==============================] - 8s 61ms/step - loss: 1.9890 - accuracy: 0.5664 - val_loss: 6.3757 - val_accuracy: 0.2827
# Epoch 156/300
# 123/123 [==============================] - 7s 60ms/step - loss: 1.9832 - accuracy: 0.5685 - val_loss: 6.3969 - val_accuracy: 0.2855
# Epoch 157/300
# 123/123 [==============================] - 7s 60ms/step - loss: 1.9786 - accuracy: 0.5686 - val_loss: 6.3934 - val_accuracy: 0.2851
# Epoch 158/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.9664 - accuracy: 0.5684 - val_loss: 6.4101 - val_accuracy: 0.2830
# Epoch 159/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.9635 - accuracy: 0.5694 - val_loss: 6.4297 - val_accuracy: 0.2812
# Epoch 160/300
# 123/123 [==============================] - 8s 67ms/step - loss: 1.9551 - accuracy: 0.5723 - val_loss: 6.4439 - val_accuracy: 0.2815
# Epoch 161/300
# 123/123 [==============================] - 7s 60ms/step - loss: 1.9488 - accuracy: 0.5741 - val_loss: 6.4486 - val_accuracy: 0.2846
# Epoch 162/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.9425 - accuracy: 0.5739 - val_loss: 6.4761 - val_accuracy: 0.2820
# Epoch 163/300
# 123/123 [==============================] - 8s 65ms/step - loss: 1.9364 - accuracy: 0.5768 - val_loss: 6.4822 - val_accuracy: 0.2835
# Epoch 164/300
# 123/123 [==============================] - 8s 66ms/step - loss: 1.9297 - accuracy: 0.5773 - val_loss: 6.4961 - val_accuracy: 0.2798
# Epoch 165/300
# 123/123 [==============================] - 8s 62ms/step - loss: 1.9215 - accuracy: 0.5797 - val_loss: 6.4962 - val_accuracy: 0.2824
# Epoch 166/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.9171 - accuracy: 0.5805 - val_loss: 6.5200 - val_accuracy: 0.2816
# Epoch 167/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.9124 - accuracy: 0.5820 - val_loss: 6.5368 - val_accuracy: 0.2805
# Epoch 168/300
# 123/123 [==============================] - 8s 66ms/step - loss: 1.9020 - accuracy: 0.5826 - val_loss: 6.5418 - val_accuracy: 0.2852
# Epoch 169/300
# 123/123 [==============================] - 7s 60ms/step - loss: 1.8981 - accuracy: 0.5838 - val_loss: 6.5571 - val_accuracy: 0.2815
# Epoch 170/300
# 123/123 [==============================] - 7s 56ms/step - loss: 1.8913 - accuracy: 0.5858 - val_loss: 6.5637 - val_accuracy: 0.2812
# Epoch 171/300
# 123/123 [==============================] - 7s 56ms/step - loss: 1.8848 - accuracy: 0.5858 - val_loss: 6.5833 - val_accuracy: 0.2812
# Epoch 172/300
# 123/123 [==============================] - 7s 56ms/step - loss: 1.8792 - accuracy: 0.5880 - val_loss: 6.6023 - val_accuracy: 0.2808
# Epoch 173/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.8712 - accuracy: 0.5874 - val_loss: 6.6090 - val_accuracy: 0.2791
# Epoch 174/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.8703 - accuracy: 0.5888 - val_loss: 6.6256 - val_accuracy: 0.2787
# Epoch 175/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.8617 - accuracy: 0.5910 - val_loss: 6.6341 - val_accuracy: 0.2795
# Epoch 176/300
# 123/123 [==============================] - 8s 63ms/step - loss: 1.8545 - accuracy: 0.5928 - val_loss: 6.6486 - val_accuracy: 0.2844
# Epoch 177/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.8514 - accuracy: 0.5925 - val_loss: 6.6527 - val_accuracy: 0.2800
# Epoch 178/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.8462 - accuracy: 0.5945 - val_loss: 6.6733 - val_accuracy: 0.2787
# Epoch 179/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.8376 - accuracy: 0.5939 - val_loss: 6.6810 - val_accuracy: 0.2786
# Epoch 180/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.8317 - accuracy: 0.5970 - val_loss: 6.7034 - val_accuracy: 0.2784
# Epoch 181/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.8282 - accuracy: 0.5977 - val_loss: 6.7103 - val_accuracy: 0.2795
# Epoch 182/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.8194 - accuracy: 0.5995 - val_loss: 6.7254 - val_accuracy: 0.2786
# Epoch 183/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.8128 - accuracy: 0.6022 - val_loss: 6.7422 - val_accuracy: 0.2779
# Epoch 184/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.8112 - accuracy: 0.5992 - val_loss: 6.7550 - val_accuracy: 0.2800
# Epoch 185/300
# 123/123 [==============================] - 8s 64ms/step - loss: 1.8063 - accuracy: 0.6010 - val_loss: 6.7683 - val_accuracy: 0.2783
# Epoch 186/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.7988 - accuracy: 0.6029 - val_loss: 6.7763 - val_accuracy: 0.2822
# Epoch 187/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.7951 - accuracy: 0.6042 - val_loss: 6.7895 - val_accuracy: 0.2765
# Epoch 188/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.7868 - accuracy: 0.6051 - val_loss: 6.7973 - val_accuracy: 0.2802
# Epoch 189/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.7874 - accuracy: 0.6056 - val_loss: 6.8002 - val_accuracy: 0.2779
# Epoch 190/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.7771 - accuracy: 0.6062 - val_loss: 6.8267 - val_accuracy: 0.2761
# Epoch 191/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.7717 - accuracy: 0.6092 - val_loss: 6.8539 - val_accuracy: 0.2748
# Epoch 192/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.7671 - accuracy: 0.6075 - val_loss: 6.8454 - val_accuracy: 0.2794
# Epoch 193/300
# 123/123 [==============================] - 8s 64ms/step - loss: 1.7630 - accuracy: 0.6094 - val_loss: 6.8550 - val_accuracy: 0.2782
# Epoch 194/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.7538 - accuracy: 0.6121 - val_loss: 6.8774 - val_accuracy: 0.2786
# Epoch 195/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.7511 - accuracy: 0.6115 - val_loss: 6.8890 - val_accuracy: 0.2795
# Epoch 196/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.7475 - accuracy: 0.6128 - val_loss: 6.9022 - val_accuracy: 0.2790
# Epoch 197/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.7444 - accuracy: 0.6122 - val_loss: 6.9211 - val_accuracy: 0.2758
# Epoch 198/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.7389 - accuracy: 0.6141 - val_loss: 6.9205 - val_accuracy: 0.2780
# Epoch 199/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.7293 - accuracy: 0.6161 - val_loss: 6.9467 - val_accuracy: 0.2769
# Epoch 200/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.7250 - accuracy: 0.6159 - val_loss: 6.9531 - val_accuracy: 0.2754
# Epoch 201/300
# 123/123 [==============================] - 7s 60ms/step - loss: 1.7193 - accuracy: 0.6180 - val_loss: 6.9473 - val_accuracy: 0.2764
# Epoch 202/300
# 123/123 [==============================] - 8s 64ms/step - loss: 1.7146 - accuracy: 0.6195 - val_loss: 6.9678 - val_accuracy: 0.2772
# Epoch 203/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.7098 - accuracy: 0.6200 - val_loss: 6.9955 - val_accuracy: 0.2755
# Epoch 204/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.7055 - accuracy: 0.6215 - val_loss: 7.0175 - val_accuracy: 0.2758
# Epoch 205/300
# 123/123 [==============================] - 7s 56ms/step - loss: 1.7036 - accuracy: 0.6213 - val_loss: 7.0090 - val_accuracy: 0.2736
# Epoch 206/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.6964 - accuracy: 0.6233 - val_loss: 7.0252 - val_accuracy: 0.2729
# Epoch 207/300
# 123/123 [==============================] - 7s 56ms/step - loss: 1.6895 - accuracy: 0.6236 - val_loss: 7.0359 - val_accuracy: 0.2764
# Epoch 208/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.6886 - accuracy: 0.6245 - val_loss: 7.0626 - val_accuracy: 0.2753
# Epoch 209/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.6833 - accuracy: 0.6261 - val_loss: 7.0582 - val_accuracy: 0.2739
# Epoch 210/300
# 123/123 [==============================] - 8s 65ms/step - loss: 1.6802 - accuracy: 0.6273 - val_loss: 7.0725 - val_accuracy: 0.2714
# Epoch 211/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.6742 - accuracy: 0.6263 - val_loss: 7.0735 - val_accuracy: 0.2758
# Epoch 212/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.6696 - accuracy: 0.6309 - val_loss: 7.0792 - val_accuracy: 0.2735
# Epoch 213/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.6646 - accuracy: 0.6292 - val_loss: 7.1174 - val_accuracy: 0.2753
# Epoch 214/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.6605 - accuracy: 0.6295 - val_loss: 7.1127 - val_accuracy: 0.2748
# Epoch 215/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.6542 - accuracy: 0.6316 - val_loss: 7.1354 - val_accuracy: 0.2758
# Epoch 216/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.6528 - accuracy: 0.6316 - val_loss: 7.1485 - val_accuracy: 0.2719
# Epoch 217/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.6461 - accuracy: 0.6328 - val_loss: 7.1631 - val_accuracy: 0.2764
# Epoch 218/300
# 123/123 [==============================] - 8s 65ms/step - loss: 1.6418 - accuracy: 0.6339 - val_loss: 7.1643 - val_accuracy: 0.2744
# Epoch 219/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.6421 - accuracy: 0.6336 - val_loss: 7.1691 - val_accuracy: 0.2748
# Epoch 220/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.6359 - accuracy: 0.6344 - val_loss: 7.1976 - val_accuracy: 0.2735
# Epoch 221/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.6278 - accuracy: 0.6343 - val_loss: 7.2050 - val_accuracy: 0.2736
# Epoch 222/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.6256 - accuracy: 0.6362 - val_loss: 7.2194 - val_accuracy: 0.2735
# Epoch 223/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.6197 - accuracy: 0.6382 - val_loss: 7.2108 - val_accuracy: 0.2747
# Epoch 224/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.6172 - accuracy: 0.6402 - val_loss: 7.2255 - val_accuracy: 0.2755
# Epoch 225/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.6152 - accuracy: 0.6386 - val_loss: 7.2594 - val_accuracy: 0.2776
# Epoch 226/300
# 123/123 [==============================] - 8s 62ms/step - loss: 1.6118 - accuracy: 0.6392 - val_loss: 7.2586 - val_accuracy: 0.2751
# Epoch 227/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.6022 - accuracy: 0.6397 - val_loss: 7.2413 - val_accuracy: 0.2750
# Epoch 228/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.5999 - accuracy: 0.6429 - val_loss: 7.2807 - val_accuracy: 0.2733
# Epoch 229/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.5925 - accuracy: 0.6431 - val_loss: 7.2917 - val_accuracy: 0.2700
# Epoch 230/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.5924 - accuracy: 0.6428 - val_loss: 7.3137 - val_accuracy: 0.2717
# Epoch 231/300
# 123/123 [==============================] - 7s 60ms/step - loss: 1.5861 - accuracy: 0.6456 - val_loss: 7.3094 - val_accuracy: 0.2743
# Epoch 232/300
# 123/123 [==============================] - 8s 63ms/step - loss: 1.5834 - accuracy: 0.6441 - val_loss: 7.3271 - val_accuracy: 0.2735
# Epoch 233/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.5787 - accuracy: 0.6463 - val_loss: 7.3454 - val_accuracy: 0.2714
# Epoch 234/300
# 123/123 [==============================] - 7s 60ms/step - loss: 1.5740 - accuracy: 0.6469 - val_loss: 7.3551 - val_accuracy: 0.2742
# Epoch 235/300
# 123/123 [==============================] - 8s 63ms/step - loss: 1.5681 - accuracy: 0.6491 - val_loss: 7.3403 - val_accuracy: 0.2722
# Epoch 236/300
# 123/123 [==============================] - 7s 60ms/step - loss: 1.5697 - accuracy: 0.6482 - val_loss: 7.3754 - val_accuracy: 0.2722
# Epoch 237/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.5620 - accuracy: 0.6490 - val_loss: 7.3978 - val_accuracy: 0.2751
# Epoch 238/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.5594 - accuracy: 0.6492 - val_loss: 7.3734 - val_accuracy: 0.2732
# Epoch 239/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.5545 - accuracy: 0.6507 - val_loss: 7.4000 - val_accuracy: 0.2717
# Epoch 240/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.5518 - accuracy: 0.6510 - val_loss: 7.4111 - val_accuracy: 0.2728
# Epoch 241/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.5473 - accuracy: 0.6533 - val_loss: 7.4052 - val_accuracy: 0.2715
# Epoch 242/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.5450 - accuracy: 0.6514 - val_loss: 7.4368 - val_accuracy: 0.2736
# Epoch 243/300
# 123/123 [==============================] - 8s 66ms/step - loss: 1.5435 - accuracy: 0.6527 - val_loss: 7.4365 - val_accuracy: 0.2700
# Epoch 244/300
# 123/123 [==============================] - 7s 60ms/step - loss: 1.5384 - accuracy: 0.6519 - val_loss: 7.4563 - val_accuracy: 0.2755
# Epoch 245/300
# 123/123 [==============================] - 7s 61ms/step - loss: 1.5355 - accuracy: 0.6540 - val_loss: 7.4794 - val_accuracy: 0.2735
# Epoch 246/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.5300 - accuracy: 0.6531 - val_loss: 7.4634 - val_accuracy: 0.2722
# Epoch 247/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.5277 - accuracy: 0.6547 - val_loss: 7.4869 - val_accuracy: 0.2735
# Epoch 248/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.5205 - accuracy: 0.6573 - val_loss: 7.5029 - val_accuracy: 0.2729
# Epoch 249/300
# 123/123 [==============================] - 7s 60ms/step - loss: 1.5183 - accuracy: 0.6575 - val_loss: 7.4962 - val_accuracy: 0.2697
# Epoch 250/300
# 123/123 [==============================] - 7s 60ms/step - loss: 1.5156 - accuracy: 0.6589 - val_loss: 7.5186 - val_accuracy: 0.2721
# Epoch 251/300
# 123/123 [==============================] - 8s 66ms/step - loss: 1.5119 - accuracy: 0.6591 - val_loss: 7.5303 - val_accuracy: 0.2713
# Epoch 252/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.5094 - accuracy: 0.6601 - val_loss: 7.5334 - val_accuracy: 0.2728
# Epoch 253/300
# 123/123 [==============================] - 7s 60ms/step - loss: 1.5024 - accuracy: 0.6617 - val_loss: 7.5430 - val_accuracy: 0.2721
# Epoch 254/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.5011 - accuracy: 0.6615 - val_loss: 7.5727 - val_accuracy: 0.2699
# Epoch 255/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.4975 - accuracy: 0.6626 - val_loss: 7.5790 - val_accuracy: 0.2710
# Epoch 256/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.4941 - accuracy: 0.6622 - val_loss: 7.5841 - val_accuracy: 0.2702
# Epoch 257/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.4911 - accuracy: 0.6648 - val_loss: 7.5913 - val_accuracy: 0.2724
# Epoch 258/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.4829 - accuracy: 0.6647 - val_loss: 7.5866 - val_accuracy: 0.2697
# Epoch 259/300
# 123/123 [==============================] - 8s 64ms/step - loss: 1.4863 - accuracy: 0.6622 - val_loss: 7.6147 - val_accuracy: 0.2686
# Epoch 260/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.4794 - accuracy: 0.6658 - val_loss: 7.6166 - val_accuracy: 0.2695
# Epoch 261/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.4603 - accuracy: 0.6687 - val_loss: 7.7045 - val_accuracy: 0.2719
# Epoch 267/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.4567 - accuracy: 0.6700 - val_loss: 7.6784 - val_accuracy: 0.2699
# Epoch 268/300
# 123/123 [==============================] - 8s 63ms/step - loss: 1.4513 - accuracy: 0.6705 - val_loss: 7.6990 - val_accuracy: 0.2706
# Epoch 269/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.4474 - accuracy: 0.6731 - val_loss: 7.7070 - val_accuracy: 0.2695
# Epoch 270/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.4471 - accuracy: 0.6723 - val_loss: 7.7207 - val_accuracy: 0.2707
# Epoch 271/300
# 123/123 [==============================] - 8s 63ms/step - loss: 1.4437 - accuracy: 0.6725 - val_loss: 7.7252 - val_accuracy: 0.2693
# Epoch 272/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.4383 - accuracy: 0.6745 - val_loss: 7.7426 - val_accuracy: 0.2715
# Epoch 273/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.4334 - accuracy: 0.6756 - val_loss: 7.7452 - val_accuracy: 0.2688
# Epoch 274/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.4368 - accuracy: 0.6764 - val_loss: 7.7533 - val_accuracy: 0.2688
# Epoch 275/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.4288 - accuracy: 0.6763 - val_loss: 7.7549 - val_accuracy: 0.2682
# Epoch 276/300
# 123/123 [==============================] - 8s 65ms/step - loss: 1.4251 - accuracy: 0.6762 - val_loss: 7.7816 - val_accuracy: 0.2681
# Epoch 277/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.4234 - accuracy: 0.6769 - val_loss: 7.8010 - val_accuracy: 0.2703
# Epoch 278/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.4225 - accuracy: 0.6776 - val_loss: 7.7889 - val_accuracy: 0.2693
# Epoch 279/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.4194 - accuracy: 0.6791 - val_loss: 7.8109 - val_accuracy: 0.2696
# Epoch 280/300
# 123/123 [==============================] - 7s 60ms/step - loss: 1.4167 - accuracy: 0.6776 - val_loss: 7.8310 - val_accuracy: 0.2686
# Epoch 281/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.4141 - accuracy: 0.6793 - val_loss: 7.8416 - val_accuracy: 0.2685
# Epoch 282/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.4127 - accuracy: 0.6792 - val_loss: 7.8426 - val_accuracy: 0.2675
# Epoch 283/300
# 123/123 [==============================] - 7s 60ms/step - loss: 1.4051 - accuracy: 0.6797 - val_loss: 7.8497 - val_accuracy: 0.2671
# Epoch 284/300
# 123/123 [==============================] - 8s 66ms/step - loss: 1.3956 - accuracy: 0.6828 - val_loss: 7.8639 - val_accuracy: 0.2679
# Epoch 285/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.3949 - accuracy: 0.6821 - val_loss: 7.8557 - val_accuracy: 0.2689
# Epoch 286/300
# 123/123 [==============================] - 7s 60ms/step - loss: 1.3964 - accuracy: 0.6821 - val_loss: 7.8799 - val_accuracy: 0.2646
# Epoch 287/300
# 123/123 [==============================] - 7s 60ms/step - loss: 1.3917 - accuracy: 0.6836 - val_loss: 7.8908 - val_accuracy: 0.2662
# Epoch 288/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.3903 - accuracy: 0.6827 - val_loss: 7.8994 - val_accuracy: 0.2682
# Epoch 289/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.3885 - accuracy: 0.6836 - val_loss: 7.8960 - val_accuracy: 0.2653
# Epoch 290/300
# 123/123 [==============================] - 7s 59ms/step - loss: 1.3840 - accuracy: 0.6838 - val_loss: 7.9122 - val_accuracy: 0.2667
# Epoch 291/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.3816 - accuracy: 0.6863 - val_loss: 7.9150 - val_accuracy: 0.2671
# Epoch 292/300
# 123/123 [==============================] - 8s 64ms/step - loss: 1.3787 - accuracy: 0.6853 - val_loss: 7.9226 - val_accuracy: 0.2677
# Epoch 293/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.3783 - accuracy: 0.6854 - val_loss: 7.9386 - val_accuracy: 0.2655
# Epoch 294/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.3738 - accuracy: 0.6879 - val_loss: 7.9410 - val_accuracy: 0.2675
# Epoch 295/300
# 123/123 [==============================] - 7s 60ms/step - loss: 1.3714 - accuracy: 0.6880 - val_loss: 7.9532 - val_accuracy: 0.2673
# Epoch 296/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.3642 - accuracy: 0.6882 - val_loss: 7.9683 - val_accuracy: 0.2685
# Epoch 297/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.3654 - accuracy: 0.6887 - val_loss: 7.9821 - val_accuracy: 0.2646
# Epoch 298/300
# 123/123 [==============================] - 7s 57ms/step - loss: 1.3604 - accuracy: 0.6884 - val_loss: 7.9940 - val_accuracy: 0.2644
# Epoch 299/300
# 123/123 [==============================] - 7s 58ms/step - loss: 1.3592 - accuracy: 0.6900 - val_loss: 7.9936 - val_accuracy: 0.2678
# Epoch 300/300
# 123/123 [==============================] - 8s 64ms/step - loss: 1.3536 - accuracy: 0.6925 - val_loss: 8.0153 - val_accuracy: 0.2620

# %%
import numpy as np

# %%
from tensorflow.keras.models import Model

# Define encoder model to get encoder states
encoder_model = Model(encoder_inputs, encoder_states)

# Define decoder model with encoder states as initial state
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_inputs_single = Input(shape=(1,))
decoder_inputs_single_embedded = decoder_embedding(decoder_inputs_single)

decoder_outputs, state_h, state_c = decoder_lstm(decoder_inputs_single_embedded, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = Model([decoder_inputs_single] + decoder_states_inputs, [decoder_outputs] + decoder_states)

# Helper function to generate a response given an input sequence
def generate_response(input_seq):
    # Encode the input sequence to get the initial decoder states
    states_value = encoder_model.predict(input_seq)

    # Initialize the target sequence with a start token
    target_seq = np.array([[tokenizer.word_index['sos']]])

    stop_condition = False
    response = []

    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token from the output distribution
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        
        # If the predicted word index is 0, use a period instead
        if sampled_token_index == 0:
            sampled_token = '.'
        else:
            sampled_token = tokenizer.index_word[sampled_token_index]
        
        response.append(sampled_token)

        # Exit condition: either hit max length or find stop token
        if sampled_token == 'eos' or len(response) > max_seq_length:
            stop_condition = True

        # Update the target sequence with the sampled token
        target_seq = np.array([[sampled_token_index]])

        # Update the decoder states
        states_value = [h, c]

    return ' '.join(response)

# %%
# Test the response generation
input_sequence = tokenizer.texts_to_sequences(["Little tyke fell asleep just as we were flying over Bristol."])
input_sequence = pad_sequences(input_sequence, maxlen=max_seq_length, padding='post', truncating='post')
response = generate_response(input_sequence)
print("Input:", f'{input_sequence}')
print("Response:", response)
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# Input: [[ 138 1708  589  791   55   71   23  102  681  179]]
# Response: it ' s not a term one usually hears in the
